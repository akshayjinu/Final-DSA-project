# %%
# importing the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Loading and preparing data

# %%
# Load the dataset
employee = pd.read_csv('/content/Employee.csv')

# %%
employee.head()
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education          5390.0
# 1        64756   59  Female                 4       Media          5534.0
# 2        30257   24  Female                10  Healthcare          8159.0
# 3        65791   36  Female                 7   Education          3989.0
# 4        65026   56    Male                41   Education          4821.0
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                   2.0
# 1              Poor             High                Low                   3.0
# 2              Good             High                Low                   0.0
# 3              Good             High               High                   1.0
# 4              Fair        Very High            Average                   0.0
#
# ...

# %%
employee.tail()
# Out:
#        Age  Gender  Years at Company    Job Role  Monthly Income  \
# 16238   34    Male                25  Technology          7949.0
# 16239   19  Female                 4   Education          5228.0
# 16240   38    Male                 1       Media          5599.0
# 16241   49    Male                 6     Finance          7819.0
# 16242   39  Female                30       Educa             NaN
#
#       Work-Life Balance Job Satisfaction Performance Rating  \
# 16238              Good              Low                Low
# 16239              Fair        Very High            Average
# 16240              Good           Medium            Average
# 16241         Excellent              Low      Below Average
# 16242               NaN              NaN                NaN
#
#        Number of Promotions Overtime  ...  Number of Dependents Job Level  \
# 16238                   0.0       No  ...                   0.0       Mid
# ...

# %%
employee.shape
# Out:
# (16243, 24)

# %%
#Checking for info
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16243 entries, 0 to 16242
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               16243 non-null  int64
#  1   Age                       16243 non-null  int64
#  2   Gender                    16243 non-null  object
#  3   Years at Company          16243 non-null  int64
#  4   Job Role                  16243 non-null  object
#  5   Monthly Income            16242 non-null  float64
#  6   Work-Life Balance         16242 non-null  object
#  7   Job Satisfaction          16242 non-null  object
#  8   Performance Rating        16242 non-null  object
#  9   Number of Promotions      16242 non-null  float64
#  10  Overtime                  16242 non-null  object
#  11  Distance from Home        16242 non-null  float64
#  12  Education Level           16241 non-null  object
# ...

# %%
# checking for duplicated values
employee.duplicated().sum()
# Out:
# 0

# %%
# checking the datatypes for each columns
employee.dtypes
# Out:
# Employee ID                   int64
# Age                           int64
# Gender                       object
# Years at Company              int64
# Job Role                     object
# Monthly Income              float64
# Work-Life Balance            object
# Job Satisfaction             object
# Performance Rating           object
# Number of Promotions        float64
# Overtime                     object
# Distance from Home          float64
# Education Level              object
# Marital Status               object
# Number of Dependents        float64
# Job Level                    object
# Company Size                 object
# Company Tenure              float64
# Remote Work                  object
# Leadership Opportunities     object
# Innovation Opportunities     object
# Company Reputation           object
# Employee Recognition         object
# Attrition                    object
# dtype: object

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %%
# Checking the data distribution of the dataset
employee.describe()
# Out:
#         Employee ID           Age  Years at Company  Monthly Income  \
# count  16243.000000  16243.000000      16243.000000    16242.000000
# mean   37321.475159     38.532168         15.757926     7300.326745
# std    21426.130679     12.128042         11.323468     2150.872721
# min        1.000000     18.000000          1.000000     1575.000000
# 25%    18880.500000     28.000000          7.000000     5672.250000
# 50%    37265.000000     39.000000         13.000000     7333.000000
# 75%    55844.000000     49.000000         23.000000     8876.000000
# max    74496.000000     59.000000         51.000000    15495.000000
#
#        Number of Promotions  Distance from Home  Number of Dependents  \
# count          16242.000000        16242.000000          16242.000000
# mean               0.831178           49.606145              1.649489
# std                0.991718           28.606763              1.552273
# min                0.000000            1.000000              0.000000
# ...

# %%
employee.columns
# Out:
# Index(['Employee ID', 'Age', 'Gender', 'Years at Company', 'Job Role',
#        'Monthly Income', 'Work-Life Balance', 'Job Satisfaction',
#        'Performance Rating', 'Number of Promotions', 'Overtime',
#        'Distance from Home', 'Education Level', 'Marital Status',
#        'Number of Dependents', 'Job Level', 'Company Size', 'Company Tenure',
#        'Remote Work', 'Leadership Opportunities', 'Innovation Opportunities',
#        'Company Reputation', 'Employee Recognition', 'Attrition'],
#       dtype='object')

# %%
employee.drop(['Employee ID'],axis=1,inplace=True)

# %%
gender=employee['Gender'].value_counts()
gender
# Out:
# Gender
# Male      8852
# Female    7391
# Name: count, dtype: int64

# %%
employee['Gender'].value_counts().plot(kind='bar',color=['salmon','lightblue'],title="Count of different gender")
# Out:
# <Axes: title={'center': 'Count of different gender'}, xlabel='Gender'>

# %% [markdown]
# Here we can see from this chart,it's visible that the count of males is more than female
#
#
# *   Male: 8852
# *   female: 7391

# %%
# create a plot for crosstab
pd.crosstab(employee['Gender'],employee['Attrition']).plot(kind="bar",figsize=(10,6))
plt.title("Attrition Vs Gender")
plt.xlabel("Attrition")
plt.ylabel(" No of people who left base on gender")
plt.legend(["left","Stayed"])
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, 'Female'), Text(1, 0, 'Male')])

# %% [markdown]
# Here, we can see from the chart, we can see that it's either male or female leff the company

# %% [markdown]
# ###Promotion

# %%
promotion = employee['Number of Promotions'].value_counts()
promotion
# Out:
# Number of Promotions
# 0.0    8097
# 1.0    4072
# 2.0    3001
# 3.0     862
# 4.0     210
# Name: count, dtype: int64

# %% [markdown]
# ### Monthly income

# %%
mon_income= employee['Monthly Income'].value_counts()
mon_income
# Out:
# Monthly Income
# 8392.0     9
# 6481.0     9
# 8220.0     9
# 9101.0     8
# 9487.0     8
#           ..
# 4191.0     1
# 8884.0     1
# 4406.0     1
# 10514.0    1
# 7819.0     1
# Name: count, Length: 7160, dtype: int64

# %% [markdown]
# ### Maritial Status

# %%
Maritial_status = employee['Marital Status'].value_counts()
Maritial_status
# Out:
# Marital Status
# Married     8135
# Single      5675
# Divorced    2432
# Name: count, dtype: int64

# %% [markdown]
# ### Job Role

# %%
job_role = employee['Job Role'].value_counts()
job_role
# Out:
# Job Role
# Technology    4306
# Healthcare    3645
# Education     3365
# Media         2665
# Finance       2261
# Educa            1
# Name: count, dtype: int64

# %% [markdown]
# ## Preprocessing

# %%
employee.dtypes
# Out:
# Age                           int64
# Gender                       object
# Years at Company              int64
# Job Role                     object
# Monthly Income              float64
# Work-Life Balance            object
# Job Satisfaction             object
# Performance Rating           object
# Number of Promotions        float64
# Overtime                     object
# Distance from Home          float64
# Education Level              object
# Marital Status               object
# Number of Dependents        float64
# Job Level                    object
# Company Size                 object
# Company Tenure              float64
# Remote Work                  object
# Leadership Opportunities     object
# Innovation Opportunities     object
# Company Reputation           object
# Employee Recognition         object
# Attrition                    object
# dtype: object

# %%
# checking for null values
employee.isnull().sum().sort_values(ascending=False)
# Out:
# Education Level             2
# Remote Work                 2
# Job Level                   2
# Marital Status              1
# Employee Recognition        1
# Company Reputation          1
# Innovation Opportunities    1
# Leadership Opportunities    1
# Company Tenure              1
# Company Size                1
# Number of Dependents        1
# Attrition                   1
# Distance from Home          1
# Overtime                    1
# Number of Promotions        1
# Performance Rating          1
# Job Satisfaction            1
# Work-Life Balance           1
# Monthly Income              1
# Gender                      0
# Job Role                    0
# Years at Company            0
# Age                         0
# dtype: int64

# %%
employee.columns
# Out:
# Index(['Age', 'Gender', 'Years at Company', 'Job Role', 'Monthly Income',
#        'Work-Life Balance', 'Job Satisfaction', 'Performance Rating',
#        'Number of Promotions', 'Overtime', 'Distance from Home',
#        'Education Level', 'Marital Status', 'Number of Dependents',
#        'Job Level', 'Company Size', 'Company Tenure', 'Remote Work',
#        'Leadership Opportunities', 'Innovation Opportunities',
#        'Company Reputation', 'Employee Recognition', 'Attrition'],
#       dtype='object')

# %%
employee.dtypes
# Out:
# Age                           int64
# Gender                       object
# Years at Company              int64
# Job Role                     object
# Monthly Income              float64
# Work-Life Balance            object
# Job Satisfaction             object
# Performance Rating           object
# Number of Promotions        float64
# Overtime                     object
# Distance from Home          float64
# Education Level              object
# Marital Status               object
# Number of Dependents        float64
# Job Level                    object
# Company Size                 object
# Company Tenure              float64
# Remote Work                  object
# Leadership Opportunities     object
# Innovation Opportunities     object
# Company Reputation           object
# Employee Recognition         object
# Attrition                    object
# dtype: object

# %%
employee.drop(['Work-Life Balance','Performance Rating','Overtime','Distance from Home','Number of Dependents','Company Tenure','Remote Work','Leadership Opportunities','Innovation Opportunities','Company Reputation'],axis=1,inplace=True)

# %%
employee.isnull().sum().sort_values(ascending=False)
# Out:
# Education Level         2
# Job Level               2
# Monthly Income          1
# Job Satisfaction        1
# Number of Promotions    1
# Marital Status          1
# Company Size            1
# Employee Recognition    1
# Attrition               1
# Age                     0
# Gender                  0
# Years at Company        0
# Job Role                0
# dtype: int64

# %%
employee.dtypes
# Out:
# Age                       int64
# Gender                   object
# Years at Company          int64
# Job Role                 object
# Monthly Income          float64
# Job Satisfaction         object
# Number of Promotions    float64
# Education Level          object
# Marital Status           object
# Job Level                object
# Company Size             object
# Employee Recognition     object
# Attrition                object
# dtype: object

# %%
employee.columns
# Out:
# Index(['Age', 'Gender', 'Years at Company', 'Job Role', 'Monthly Income',
#        'Job Satisfaction', 'Number of Promotions', 'Education Level',
#        'Marital Status', 'Job Level', 'Company Size', 'Employee Recognition',
#        'Attrition'],
#       dtype='object')

# %%
employee['Monthly Income'].fillna(employee['Monthly Income'].mean(),inplace=True)

# %%
employee['Number of Promotions'].fillna(employee['Number of Promotions'].mean(),inplace=True)

# %%
employee['Education Level'].fillna(employee['Education Level'].mode()[0],inplace=True)
employee['Job Level'].fillna(employee['Job Level'].mode()[0],inplace=True)
employee['Marital Status'].fillna(employee['Marital Status'].mode()[0],inplace=True)
employee['Company Size'].fillna(employee['Company Size'].mode()[0],inplace=True)
employee['Attrition'].fillna(employee['Attrition'].mode()[0],inplace=True)
employee['Job Satisfaction'].fillna(employee['Job Satisfaction'].mode()[0],inplace=True)
employee['Employee Recognition'].fillna(employee['Employee Recognition'].mode()[0],inplace=True)

# %%
employee.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Years at Company        0
# Job Role                0
# Monthly Income          0
# Job Satisfaction        0
# Number of Promotions    0
# Education Level         0
# Marital Status          0
# Job Level               0
# Company Size            0
# Employee Recognition    0
# Attrition               0
# dtype: int64

# %%
#checking for outliers using boxplot
plt.figure(figsize=(10,10))
for index, column in enumerate(employee.drop(['Attrition'], axis=1).columns):
    plt.subplot(1,3,index+1)
    employee[columns].plot(kind="box")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-588e702dd8b8> in <cell line: 3>()
#       1 #checking for outliers using boxplot
#       2 plt.figure(figsize=(10,10))
# ----> 3 for index, column in enumerate(employee.drop(['Attrition'], axis=1).columns):
#       4     plt.subplot(1,3,index+1)
#       5     employee[columns].plot(kind="box")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
# ...

# %% [markdown]
# ## modelling

# %%
from sklearn.model_selection import train_test_split

X = employee.drop('Attrition', axis=1)
y = employee['Attrition']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.15, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape # Checking the shapes
# Out:
# ((13806, 12), (2437, 12), (13806,), (2437,))

# %%
#Visualize the Number of Employees that stayed and left the company
sns.countplot(employee['Attrition'], palette=['green', 'red'])
# Out:
# <ipython-input-75-b123650263ee>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(employee['Attrition'], palette=['green', 'red'])
# <Axes: xlabel='count', ylabel='Attrition'>

# %%
sns.countplot(x='Age',hue='Attrition',data=employee)
xticks=plt.xticks(rotation=90)

# %%
employee=pd.get_dummies(employee)

# %%
correlation_matrix = employee.corr()

# Display the correlation matrix
correlation_matrix
# Out:
#                                         Age  Years at Company  Monthly Income  \
# Age                                1.000000          0.548057   -1.628421e-03
# Years at Company                   0.548057          1.000000   -9.727868e-03
# Monthly Income                    -0.001628         -0.009728    1.000000e+00
# Number of Promotions               0.003579         -0.000648    1.344384e-02
# Gender_Female                     -0.003703         -0.000206   -9.985589e-03
# Gender_Male                        0.003703          0.000206    9.985589e-03
# Job Role_Educa                     0.000303          0.009869    8.294796e-17
# Job Role_Education                 0.004137          0.005616   -6.651177e-01
# Job Role_Finance                  -0.001998         -0.005901    2.314877e-01
# Job Role_Healthcare               -0.000970          0.003967    1.699579e-01
# Job Role_Media                     0.001231          0.000604   -2.727644e-01
# ...

# %%
# Visualize correlation
sns.heatmap(employee.corr())
# Out:
# <Axes: >

# %% [markdown]
# Label encoder

# %%
from sklearn.preprocessing import LabelEncoder

for column in employee.columns:
  if employee[column].dtype==np.number:
    continue
    df[column]=LabelEncoder().fit_transform(df[column])
# Out:
# <ipython-input-89-e05aba98d4c2>:4: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if employee[column].dtype==np.number:

# %%
#Split the data
X=employee.iloc[:,1:employee.shape[1]].values
Y=employee.iloc[:,0].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
# random forest Classifier
from sklearn.ensemble import RandomForestClassifier
forest=RandomForestClassifier(n_estimators=100,random_state=42)
forest.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
#get the Accuracy on the Training dataset
Randomforest.score(X_train,Y_train)
# Out:
# 1.0

# %%
#Confusion Matrix and and accuracy for the model on the test data
from sklearn.metrics import confusion_matrix,classification_report
Y_pred=forest.predict(X_test)
cm=confusion_matrix(Y_test,Y_pred)

# %%
TN=cm[0][0]
TP=cm[1][1]
FN=cm[1][0]
FP=cm[0][1]
print('Testing Accuracy=',(TP+TN)/(TP+TN+FN+FP))
# Out:
# Testing Accuracy= 0.3333333333333333
